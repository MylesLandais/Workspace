# %%
import importlib
import runpod_runner
importlib.reload(runpod_runner)
from runpod_runner import run_workflow

results = run_workflow('flux_dev_full_text_to_image(2)(1).json')

# The error details should now be printed
# You can also inspect them:
if not results['success'] and results['status_data']:
    print("\n[DEBUG] You can inspect: results['status_data']")
# Out:
# ...
# RunPod Workflow Runner - Notebook Mode
# ...
#
# Quick Start:
#   results = run_workflow('workflow.json')
#   results = run_workflow('workflow.json', seed=12345)
#
# Advanced Usage:
#   runner = RunPodWorkflowRunner()
#   results = runner.run('workflow.json', output_dir='my_images')
#
# Results structure:
#   results['success']     - True/False
#   results['job_id']      - RunPod job ID
#   results['files']       - List of saved image paths
#   results['status_data'] - Full API response
# ...
#
# [INIT] RunPod runner initialized with endpoint: a48mrbdsbzg35n
#
# ...
# Running workflow: flux_dev_full_text_to_image(2)(1).json
# ...
#
# [OK] Loaded workflow from: flux_dev_full_text_to_image(2)(1).json
# [OK] Updated KSampler seed to: 2414116800
# [SUBMIT] Sending request to RunPod...
# [OK] Job started with ID: fe24b4f6-3859-4e20-9774-a27c34da2473-u1
# [POLL] Checking job status (timeout: 600s)...
# [ERROR] Job failed with status: FAILED
#
# [ERROR] Full response:
# {
#   "delayTime": 430,
# ...

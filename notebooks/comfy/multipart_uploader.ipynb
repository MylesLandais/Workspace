# %%
# Out:
# ...
# STARTING UPLOAD SCRIPT
# ...
# Bucket: z6y2yim0s3
# File: /home/jovyan/ComfyUI/models/diffusion_models/Chroma1-HD-fp8_scaled_rev2.safetensors
# Key: models/diffusion_models/Chroma1-HD-fp8_scaled_rev2.safetensors
# Chunk size: 64.0 MB
# ...
# Uploader created, calling upload()...
# [2025-11-14 22:52:24,454]     INFO Uploading: /home/jovyan/ComfyUI/models/diffusion_models/Chroma1-HD-fp8_scaled_rev2.safetensors
# [2025-11-14 22:52:24,454]     INFO Size: 8.29 GB in 133 parts of 64 MB
# [2025-11-14 22:52:24,455]     INFO Destination: s3://z6y2yim0s3/models/diffusion_models/Chroma1-HD-fp8_scaled_rev2.safetensors
# [2025-11-14 22:52:24,977]     INFO Upload ID: 1763178744943003278_z6y2yim0s3__models_diffusion_models_Chroma1-HD-fp8_scaled_rev2.safetensors
# [Part 1/133] Starting upload...
# [Part 2/133] Starting upload...
# [Part 3/133] Starting upload...
# [Part 4/133] Starting upload...
# ...

# %%
"""Environment configuration loader with interactive setup."""
## TODO:: Something about automagically making sure pip install happens if missing dependencies

import os
from pathlib import Path
from getpass import getpass
from typing import List, Optional
from dotenv import load_dotenv
import sys

# SNIPPETS (needs cleaning up)
# Add the 'src' directory to Python's search path
sys.path.append(os.path.abspath("src"))

# If your code is actually in the 'agents' folder, uncomment the line below instead:
sys.path.append(os.path.abspath("agents"))

class EnvironmentConfig:
    """Manages loading and validation of environment variables."""
    
    REQUIRED_VARS = [
        "OPENROUTER_API_KEY",
        "RUNPOD_API_KEY",
        "RUNPOD_ENDPOINT_ID"
    ]
    
    def __init__(self, env_path: Optional[Path] = None):
        """Initialize configuration loader.
        
        Args:
            env_path: Path to .env file. Defaults to ~/workspace/.env
        """
        self.env_path = env_path or Path.home() / "workspace" / ".env"
        self._load_environment()
    
    def _load_environment(self) -> None:
        """Load environment variables from .env file."""
        load_dotenv(self.env_path, override=True)
        print(f"Environment source: {self.env_path}\n")
    
    def _prompt_for_missing_var(self, var_name: str) -> None:
        """Prompt user for missing environment variable.
        
        Args:
            var_name: Name of the environment variable
        """
        print(f"WARNING: {var_name} not found in .env file.")
        print("Please review the README or .env.example for setup instructions.")
        
        user_input = getpass(f"Please enter value for {var_name}: ")
        
        if user_input.strip():
            os.environ[var_name] = user_input.strip()
        else:
            print(f"Skipping {var_name} (no input provided)...")
    
    def _display_var_status(self, var_name: str) -> None:
        """Display the status of an environment variable.
        
        Args:
            var_name: Name of the environment variable
        """
        value = os.getenv(var_name)
        
        if value:
            print(f"{var_name:<25}: {value[:5]}...")
        else:
            print(f"{var_name:<25}: MISSING")
    
    def validate_and_setup(self) -> None:
        """Validate required variables and prompt for missing ones."""
        for var in self.REQUIRED_VARS:
            if not os.getenv(var):
                self._prompt_for_missing_var(var)
            
            self._display_var_status(var)
        
        print("-" * 40)
        self._raise_if_missing()
    
    def _raise_if_missing(self) -> None:
        """Raise ValueError if any required variables are missing."""
        missing = [var for var in self.REQUIRED_VARS if not os.getenv(var)]
        
        if missing:
            raise ValueError(
                f"Critical configuration missing: {', '.join(missing)}"
            )
    
    @classmethod
    def setup(cls, env_path: Optional[Path] = None) -> "EnvironmentConfig":
        """Convenience method to load and validate configuration.
        
        Args:
            env_path: Path to .env file. Defaults to ~/workspace/.env
            
        Returns:
            Configured EnvironmentConfig instance
            
        Raises:
            ValueError: If required variables are missing after prompting
        """
        config = cls(env_path)
        config.validate_and_setup()
        return config


# Usage
if __name__ == "__main__":
    config = EnvironmentConfig.setup()
# Out:
# Environment source: /home/jovyan/workspace/.env
#
# OPENROUTER_API_KEY       : sk-or...
# RUNPOD_API_KEY           : rpa_6...
# RUNPOD_ENDPOINT_ID       : a48mr...
# ----------------------------------------

# %%
import os
import google.auth

# 1. Disable Vertex AI to stop looking for Google Cloud credentials
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"

# 2. (Optional) Set dummy project values if code expects them, 
#    but we won't actually auth against them.
os.environ.setdefault("GOOGLE_CLOUD_PROJECT", "openrouter-project")
os.environ["GOOGLE_CLOUD_LOCATION"] = "global"

# --- Commented out to prevent DefaultCredentialsError ---
# _, project_id = google.auth.default()
# os.environ.setdefault("GOOGLE_CLOUD_PROJECT", project_id)
# --------------------------------------------------------

# Configuration dictionary
config = {
    "model": "google/gemini-2.5-flash-lite", # We will override this in the agent setup if needed
    "verbose": True
}

# %%
import sys
import os

# Add the 'agents' folder to the path so we can import 'blogger_agent' from inside it
sys.path.append("/home/jovyan/workspace/agents")
sys.path.append("/home/jovyan/workspace/agents/blog-writer")

import asyncio

from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from blogger_agent.agent import root_agent
from google.genai import types as genai_types


async def main():
    """Runs the agent with a sample query."""
    session_service = InMemorySessionService()
    await session_service.create_session(
        app_name="app", user_id="test_user", session_id="test_session"
    )
    runner = Runner(
        agent=root_agent, app_name="app", session_service=session_service
    )

    queries = [
        "I want to write a blog post about the new features in the latest version of the ADK.",
        "looks good, write it",
        "1",
        "looks good, I approve",
        "yes",
        "my_new_blog_post.md",
    ]

    for query in queries:
        print(f">>> {query}")
        async for event in runner.run_async(
            
            user_id="test_user",
            session_id="test_session",
            new_message=genai_types.Content(
                role="user", 
                parts=[genai_types.Part.from_text(text=query)]
            ),
        ):
            if event.is_final_response() and event.content and event.content.parts:
                print(event.content.parts[0].text)


if __name__ == "__main__":
    await main()
# Out:
# >>> I want to write a blog post about the new features in the latest version of the ADK.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# It appears there are several prominent "ADK" (Assessment and Deployment Kit, Agent Development Kit, Android Development Kit, etc.) across different platforms (Windows, Google, Android, AWS, Azure). To create a specific and accurate blog post outline, please clarify which ADK you are referring to.
#
# In the meantime, here is a general blog post outline that can be tailored once the specific ADK is identified. This outline includes sections for new features, potential code snippets, and technical deep dives, as is common when discussing updates to a development kit.
#
# ---
#
# # Title: Unveiling the Future: A Deep Dive into the Latest ADK Features (Please Specify Which ADK: Windows, Google Agent, Android, AWS, Azure, etc.)
#
# ## I. Introduction
# *   **A. Hook:** Briefly discuss the rapid evolution of technology and the importance of updated development kits in keeping pace.
# *   **B. Introducing the ADK (Placeholder for Specific ADK):**
#     *   Explain what the ADK is in general terms and its role in its respective ecosystem (e.g., for Windows deployments, AI agent development, Android app creation, etc.).
#     *   *Self-correction/Clarification Request:* "To proceed with a highly tailored outline, please specify which ADK you are referring to (e.g., Windows ADK, Google Agent Development Kit, Android Development Kit, AWS ADK, Azure SDK, etc.). The following sections will be populated with specific details once this clarification is provided."
# *   **C. What's New & Why It Matters:** Briefly touch upon the significance of this latest release and the overall impact of the new features.
#
# ## II. Key New Features in the Latest ADK (Requires Specific ADK Information)
#
# *   **A. Feature 1: [Specific Feature Name]** (e.g., "Enhanced Windows Imaging and Configuration Designer" or "Introduction of BaseToolset for Dynamic Tools" or "Jetpack Compose 2.0 Integration")
#     *   **1. Overview:** Explain what the feature is and its primary purpose.
#     *   **2. Benefits:** How does this feature improve workflows, performance, or capabilities for developers/IT pros?
#     *   **3. Use Cases:** Provide practical examples of how this feature can be utilized.
#     *   **4. Code Snippet/Example (if applicable):**
#
# >>> looks good, write it
# I'm glad you like the general outline! However, before I can start writing, I need a crucial piece of information. The outline I provided is a general template, and many sections require specifics about the ADK you're interested in.
#
# Could you please clarify **which ADK you are referring to**? For example, is it the:
#
# *   **Windows ADK**
# *   **Google Agent Development Kit**
# *   **Android Development Kit**
# *   **AWS ADK**
# *   **Azure SDK**
# *   Or another specific ADK?
#
# Once I have this detail, I can create a much more specific and accurate blog post for you.
# >>> 1
# Please clarify which ADK you are referring to: Windows, Google Agent, Android, AWS, Azure, etc. I need this information to write a specific and accurate blog post.
# >>> looks good, I approve
# I understand you've approved the *general* outline. However, to write the blog post, I critically need to know which specific ADK you're referring to. The outline itself states:
#
# "To proceed with a highly tailored outline, please specify which ADK you are referring to (e.g., Windows ADK, Google Agent Development Kit, Android Development Kit, AWS ADK, Azure SDK, etc.). The following sections will be populated with specific details once this clarification is provided."
#
# Without knowing the specific ADK (e.g., "Windows ADK" or "Android Development Kit"), I cannot fill in the details for the "Key New Features," "Technical Deep Dive," or "Getting Started" sections with accurate information.
#
# Could you please tell me **which ADK you want the blog post to be about**?
# >>> yes
# I appreciate your approval of the general structure. However, I still need you to tell me **which specific ADK** you are referring to.
#
# To write the blog post, I need to know if you're talking about the:
#
# *   **Windows ADK**
# *   **Google Agent Development Kit**
# *   **Android Development Kit**
# *   **AWS ADK**
# *   **Azure SDK**
# *   Or any other specific ADK?
#
# Please provide the name of the ADK so I can proceed with writing the blog post.
# >>> my_new_blog_post.md
# I understand that `my_new_blog_post.md` might be a filename you have in mind for your blog post.
#
# However, I am still waiting for you to tell me **which specific ADK** you want the blog post to be about. I cannot write the content of the blog post without this information.
#
# Please tell me, for example, "Windows ADK," "Android Development Kit," "Google Agent Development Kit," or any other specific ADK name.
